# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings

# %%
import missingno as msno

# %%
df=pd.read_csv('/content/StudentsPerformance.csv')
print('Success')
# Out:
# Success

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.mean()
# Out:
# <ipython-input-21-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df2=df.fillna(df.mean())
# Out:
# <ipython-input-22-e3824913f1eb>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2=df.fillna(df.mean())

# %%
df2.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df2.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df2.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.scatter(df['math score'], df['reading score'])
plt.xlabel('math score')
plt.ylabel('reading score')
plt.title('math score vs. reading score')
plt.show()

# %%
plt.scatter(df['math score'], df['writing score'])
plt.xlabel('math score')
plt.ylabel('writing score')
plt.title('math score vs. writing score')
plt.show()

# %%
plt.scatter(df['reading score'], df['writing score'])
plt.xlabel('reading score')
plt.ylabel('writing score')
plt.title('reading score vs. writing score')
plt.show()

# %%
plt.scatter(df['gender'], df['math score'])
plt.xlabel('gender')
plt.ylabel('math score')
plt.title('gender vs. math score')
plt.show()

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df['gender'].value_counts(normalize=True)
df['gender'].value_counts(dropna=True).plot.bar(color="green")
plt.title("Comparison of Male and Female")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
df['race/ethnicity'].value_counts(normalize = True)
df['race/ethnicity'].value_counts(dropna = False).plot.bar(color=['black','Red','yellow','pink'])
plt.title("Comparison of various groups")
plt.xlabel("Groups")
plt.ylabel("Count")
plt.show()

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
df['parental level of education'].value_counts(normalize = True)
df['parental level of education'].value_counts(dropna = False).plot.bar(color=['black','Red','yellow','pink'])
plt.title("Comparison of Parental Education")
plt.xlabel("Degree")
plt.ylabel("Count")
plt.show()

# %%
df['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
df['lunch'].value_counts(normalize = True)
df['lunch'].value_counts(dropna = False).plot.bar(color=['yellow','pink'])
plt.title("Comparison of Lunch")
plt.xlabel("Types of Lunch")
plt.ylabel("Count")
plt.show()

# %%
df['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
df['math score'].value_counts(normalize = True)
df['math score'].value_counts(dropna = False).plot.bar(figsize = (18,10),color='green')
plt.title("Comparison of Math Scores")
plt.xlabel("Maths Mark / Score")
plt.ylabel("Count")
plt.show()

# %%
df['reading score'].value_counts(normalize = True)
df['reading score'].value_counts(dropna = False).plot.bar(figsize = (18,10),color='orange')
plt.title("Comparison of Reading Scores")
plt.xlabel("Reading Mark / Score")
plt.ylabel("Count")
plt.show()

# %%
df['writing score'].value_counts(normalize = True)
df['writing score'].value_counts(dropna = False).plot.bar(figsize = (18,10),color='brown')
plt.title("Comparison of writing Scores")
plt.xlabel("Writing Mark / Score")
plt.ylabel("Count")
plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
Corr_mat= df[['gender', 'race/ethnicity', 'parental level of education', 'lunch',
       'test preparation course', 'math score', 'reading score',
       'writing score']].corr()
sns.heatmap(Corr_mat, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-48-8a73f6dcb80b>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   'writing score']].corr()

# %%
sns.pairplot(data=df[['gender', 'race/ethnicity', 'parental level of education', 'lunch','test preparation course', 'math score', 'reading score','writing score']])
plt.title('Pairwise Relationships')
plt.show()

# %%
x=df.drop("test preparation course",axis=1)
y=df["test preparation course"]

# %%
#Splitting data into Train and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (800, 7)

# %%
Y_train.shape
# Out:
# (800,)

# %%
X_test.shape
# Out:
# (200, 7)

# %%
Y_test.shape
# Out:
# (200,)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 29 to 102
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       800 non-null    object
#  1   race/ethnicity               800 non-null    object
#  2   parental level of education  800 non-null    object
#  3   lunch                        800 non-null    object
#  4   math score                   800 non-null    int64
#  5   reading score                800 non-null    int64
#  6   writing score                800 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 50.0+ KB
